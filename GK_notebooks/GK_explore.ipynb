# %% [markdown]
# ## Imports packages

# %%
#For  Colab 
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import warnings
warnings.filterwarnings("ignore")                     #Ignoring unnecessory warnings

import re 
import nltk                                         #Natural language processing tool-kit
from nltk.corpus import stopwords                   #Stopwords corpus
from nltk.stem import PorterStemmer                 # Stemmer

#from sklearn.feature_extraction.text import CountVectorizer          #For Bag of words
#from sklearn.feature_extraction.text import TfidfVectorizer          #For TF-IDF
from gensim.models import Word2Vec                                   #For Word2Vec

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot

from keras.layers import Embedding, LSTM, Dense, Dropout, Lambda, Flatten
from keras.models import Sequential, load_model, model_from_config
import keras.backend as K

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, cohen_kappa_score, accuracy_score

# %% [markdown]
# ## Imports data

# %%
#Local
df = pd.read_csv("../data/training_set_rel3.tsv", sep='\t', encoding='ISO-8859-1')

#Colab
#df = pd.read_csv("/content/drive/MyDrive/Automated_Essay_Scoring/data/training_set_rel3.tsv", sep='\t', encoding='ISO-8859-1')


df = df.dropna(axis=1)
df = df.drop(columns=['rater1_domain1', 'rater2_domain1'])
df = df.drop(columns=['essay_id'])
df.head()
# Out:
#    essay_set                                              essay  domain1_score
# 0          1  Dear local newspaper, I think effects computer...              8
# 1          1  Dear @CAPS1 @CAPS2, I believe that using compu...              9
# 2          1  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...              7
# 3          1  Dear Local Newspaper, @CAPS1 I have found that...             10
# 4          1  Dear @LOCATION1, I know having computers has a...              8

# %%
#df['essay'][1]

# %%
#we rescale to have all scores to be in the same interval
for i in range(len(df)):
    if df['essay_set'][i] == 1:
        df['domain1_score'][i] = df['domain1_score'][i] - 2
    elif df['essay_set'][i] == 2:
        df['domain1_score'][i] = (df['domain1_score'][i] - 1)*2
    elif df['essay_set'][i] == 3:
        df['domain1_score'][i] = (df['domain1_score'][i])*10/3
    elif df['essay_set'][i] == 4:
        df['domain1_score'][i] = (df['domain1_score'][i])*10/3
    elif df['essay_set'][i] == 5:
        df['domain1_score'][i] = (df['domain1_score'][i])*10/4
    elif df['essay_set'][i] == 6:
        df['domain1_score'][i] = (df['domain1_score'][i])*10/4
    elif df['essay_set'][i] == 7:
        df['domain1_score'][i] = (df['domain1_score'][i])/3
    elif df['essay_set'][i] == 8:
        df['domain1_score'][i] = (df['domain1_score'][i])/6

# %% [markdown]
# ## Text pre-treatment

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
len(stop_words) #finding stop words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/GuillaumeKunsch/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 179

# %%
snow = nltk.stem.SnowballStemmer('english')

corpus = []
for i in range(0, len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['essay'][i])
    review = review.lower()
    review = review.split()
    
    review = [snow.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
voc_size=5000
onehot_repr=[one_hot(words,voc_size)for words in corpus] 
type(onehot_repr)
# Out:
# list

# %%
sent_length=400
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0 ...  492 3258 4761]
#  [   0    0    0 ... 3500 1051 1707]
#  [   0    0    0 ... 1648 4919 2295]
#  ...
#  [3162 1714 4364 ... 2897 3757 1911]
#  [   0    0    0 ... 4826 2098 4811]
#  [   0    0    0 ... 3162 2433 2922]]

# %% [markdown]
# ## NN architecture

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/GuillaumeKunsch/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def essay_to_wordlist(essay_v, remove_stopwords):
    """Remove the tagged labels and word tokenize the sentence."""
    essay_v = re.sub("[^a-zA-Z]", " ", essay_v)
    words = essay_v.lower().split()
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    return (words)

def essay_to_sentences(essay_v, remove_stopwords):
    """Sentence tokenize the essay and call essay_to_wordlist() for word tokenization."""
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sentences = tokenizer.tokenize(essay_v.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(essay_to_wordlist(raw_sentence, remove_stopwords))
    return sentences

def makeFeatureVec(words, model, num_features):
    """Make Feature Vector from the words list of an Essay."""
    featureVec = np.zeros((num_features,),dtype="float32")
    num_words = 0.
    index2word_set = set(model.wv.index_to_key)
    for word in words:
        if word in index2word_set:
            num_words += 1
            featureVec = np.add(featureVec,model.wv[word])        
    featureVec = np.divide(featureVec,num_words)
    return featureVec

def getAvgFeatureVecs(essays, model, num_features):
    """Main function to generate the word vectors for word2vec model."""
    counter = 0
    essayFeatureVecs = np.zeros((len(essays),num_features),dtype="float32")
    for essay in essays:
        essayFeatureVecs[counter] = makeFeatureVec(essay, model, num_features)
        counter = counter + 1
    return essayFeatureVecs

# %%
def get_model():
    """Define the model."""
    model = Sequential()
    model.add(LSTM(300, dropout=0.4, recurrent_dropout=0.4, input_shape=[1, 300], return_sequences=True))
    model.add(LSTM(64, recurrent_dropout=0.4))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='relu'))

    model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['accuracy','mae'])
    model.summary()

    return model

# %%
X=df
y = X['domain1_score']

# %%
cv = KFold(n_splits = 5, shuffle = True)
mses = []
cohen_kappa_scores = []
accuracies = []
y_pred_list = []

count = 1
for traincv, testcv in cv.split(X):
    print("\n--------Fold {}--------\n".format(count))
    X_test, X_train, y_test, y_train = X.iloc[testcv], X.iloc[traincv], y.iloc[testcv], y.iloc[traincv]
    
    train_essays = X_train['essay']
    test_essays = X_test['essay']
    
    sentences = []
    
    for essay in train_essays:
            # Obtaining all sentences from the training essays.
            sentences += essay_to_sentences(essay, remove_stopwords = True)
            
    # Initializing variables for word2vec model.
    num_features = 300 
    min_word_count = 40
    num_workers = 4
    context = 10
    downsampling = 1e-3

    print("Training Word2Vec Model...")
    model = Word2Vec(sentences, workers=num_workers, vector_size=num_features, min_count = min_word_count, window = context, sample = downsampling)

    model.init_sims(replace=True)
    model.wv.save_word2vec_format('word2vecmodel.bin', binary=True)

    clean_train_essays = []
    
    # Generate training and testing data word vectors.
    for essay_v in train_essays:
        clean_train_essays.append(essay_to_wordlist(essay_v, remove_stopwords=True))
    trainDataVecs = getAvgFeatureVecs(clean_train_essays, model, num_features)
    
    clean_test_essays = []
    for essay_v in test_essays:
        clean_test_essays.append(essay_to_wordlist( essay_v, remove_stopwords=True ))
    testDataVecs = getAvgFeatureVecs( clean_test_essays, model, num_features )
    
    trainDataVecs = np.array(trainDataVecs)
    testDataVecs = np.array(testDataVecs)
    # Reshaping train and test vectors to 3 dimensions. (1 represnts one timestep)
    trainDataVecs = np.reshape(trainDataVecs, (trainDataVecs.shape[0], 1, trainDataVecs.shape[1]))
    testDataVecs = np.reshape(testDataVecs, (testDataVecs.shape[0], 1, testDataVecs.shape[1]))
    
    lstm_model = get_model()
    lstm_model.fit(trainDataVecs, y_train, batch_size=64, epochs=50)
    #lstm_model.load_weights('./model_weights/final_lstm.h5')
    y_pred = lstm_model.predict(testDataVecs)
    
    # Save any one of the 5 models.
    if count == 5:
         lstm_model.save('./final_lstm.h5')
    
    # Round y_pred to the nearest integer.
    y_pred_list.append(y_pred)
    y_pred_round = np.around(y_pred)
    
    # Evaluate the model on the evaluation metric. "Quadratic mean averaged Kappa"
    mse_score = mean_squared_error(y_test.values, y_pred)
    ck_score = cohen_kappa_score(np.around(y_test.values),y_pred_round,weights='quadratic')
    acc = accuracy_score(np.around(y_test.values),y_pred_round)

    print("MSE Score: {}".format(mse_score))
    print("Acc Score: {}".format(acc))
    print("Kappa Score: {}".format(ck_score))
    mses.append(mse_score)
    accuracies.append(acc)
    cohen_kappa_scores.append(ck_score)

    count += 1
# Out:
# --------Fold 1--------
#
# Training Word2Vec Model...
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 1, 300)            721200
#
#  lstm_5 (LSTM)               (None, 64)                93440
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 6s 11ms/step - loss: 10.3739 - accuracy: 0.0021 - mae: 2.4866
# Epoch 2/50
# 163/163 [==============================] - 2s 12ms/step - loss: 5.0904 - accuracy: 9.6339e-05 - mae: 1.7613
# Epoch 3/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.8643 - accuracy: 2.8902e-04 - mae: 1.7186
# Epoch 4/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.8553 - accuracy: 6.7437e-04 - mae: 1.7244
# Epoch 5/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.8008 - accuracy: 0.0013 - mae: 1.7103
# Epoch 6/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.7504 - accuracy: 0.0012 - mae: 1.7048
# Epoch 7/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.7099 - accuracy: 0.0013 - mae: 1.6891
# Epoch 8/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.7020 - accuracy: 0.0015 - mae: 1.6861
# Epoch 9/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.6902 - accuracy: 0.0020 - mae: 1.6870
# Epoch 10/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.7540 - accuracy: 0.0013 - mae: 1.7010
# Epoch 11/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.6582 - accuracy: 0.0015 - mae: 1.6778
# Epoch 12/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.6517 - accuracy: 0.0019 - mae: 1.6812
# Epoch 13/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6335 - accuracy: 0.0013 - mae: 1.6788
# Epoch 14/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5605 - accuracy: 0.0016 - mae: 1.6589
# Epoch 15/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5333 - accuracy: 0.0020 - mae: 1.6567
# Epoch 16/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5585 - accuracy: 0.0018 - mae: 1.6577
# Epoch 17/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5129 - accuracy: 0.0023 - mae: 1.6531
# Epoch 18/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.4296 - accuracy: 0.0025 - mae: 1.6370
# Epoch 19/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.4515 - accuracy: 0.0019 - mae: 1.6368
# Epoch 20/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.3735 - accuracy: 0.0017 - mae: 1.6245
# Epoch 21/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.3871 - accuracy: 0.0019 - mae: 1.6258
# Epoch 22/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.3121 - accuracy: 0.0017 - mae: 1.6090
# Epoch 23/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.2570 - accuracy: 0.0020 - mae: 1.6023
# Epoch 24/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.3024 - accuracy: 0.0018 - mae: 1.6102
# Epoch 25/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.2214 - accuracy: 0.0019 - mae: 1.6016
# Epoch 26/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.2373 - accuracy: 0.0016 - mae: 1.5982
# Epoch 27/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1473 - accuracy: 0.0032 - mae: 1.5857
# Epoch 28/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1447 - accuracy: 0.0017 - mae: 1.5840
# Epoch 29/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1584 - accuracy: 0.0022 - mae: 1.5873
# Epoch 30/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1327 - accuracy: 0.0015 - mae: 1.5764
# Epoch 31/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.2002 - accuracy: 0.0015 - mae: 1.5924
# Epoch 32/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1508 - accuracy: 0.0021 - mae: 1.5834
# Epoch 33/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1036 - accuracy: 0.0020 - mae: 1.5783
# Epoch 34/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0705 - accuracy: 0.0024 - mae: 1.5717
# Epoch 35/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0410 - accuracy: 0.0017 - mae: 1.5649
# Epoch 36/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9785 - accuracy: 0.0017 - mae: 1.5496
# Epoch 37/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9827 - accuracy: 0.0019 - mae: 1.5557
# Epoch 38/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9406 - accuracy: 0.0025 - mae: 1.5433
# Epoch 39/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9369 - accuracy: 0.0026 - mae: 1.5361
# Epoch 40/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9095 - accuracy: 0.0020 - mae: 1.5359
# Epoch 41/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9133 - accuracy: 0.0020 - mae: 1.5396
# Epoch 42/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8481 - accuracy: 0.0023 - mae: 1.5218
# Epoch 43/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.8008 - accuracy: 0.0020 - mae: 1.5123
# Epoch 44/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.8244 - accuracy: 0.0020 - mae: 1.5118
# Epoch 45/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7632 - accuracy: 0.0023 - mae: 1.5039
# Epoch 46/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7231 - accuracy: 0.0021 - mae: 1.4983
# Epoch 47/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6957 - accuracy: 0.0017 - mae: 1.4922
# Epoch 48/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7125 - accuracy: 0.0017 - mae: 1.4967
# Epoch 49/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7038 - accuracy: 0.0019 - mae: 1.4940
# Epoch 50/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7105 - accuracy: 0.0021 - mae: 1.4919
# 82/82 [==============================] - 1s 3ms/step
# MSE Score: 3.0581030293869835
# Acc Score: 0.23959938366718028
# Kappa Score: 0.5513497333229622
#
# --------Fold 2--------
#
# Training Word2Vec Model...
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 1, 300)            721200
#
#  lstm_7 (LSTM)               (None, 64)                93440
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 11ms/step - loss: 10.0500 - accuracy: 0.0030 - mae: 2.4345
# Epoch 2/50
# 163/163 [==============================] - 2s 11ms/step - loss: 5.0107 - accuracy: 9.6330e-05 - mae: 1.7407
# Epoch 3/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.8571 - accuracy: 3.8532e-04 - mae: 1.7107
# Epoch 4/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.7078 - accuracy: 5.7798e-04 - mae: 1.6912
# Epoch 5/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.6487 - accuracy: 0.0016 - mae: 1.6800
# Epoch 6/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6616 - accuracy: 0.0012 - mae: 1.6842
# Epoch 7/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6439 - accuracy: 0.0015 - mae: 1.6752
# Epoch 8/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6548 - accuracy: 0.0014 - mae: 1.6800
# Epoch 9/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6073 - accuracy: 0.0014 - mae: 1.6714
# Epoch 10/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.5965 - accuracy: 0.0016 - mae: 1.6675
# Epoch 11/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6411 - accuracy: 0.0013 - mae: 1.6750
# Epoch 12/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5751 - accuracy: 0.0015 - mae: 1.6578
# Epoch 13/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5434 - accuracy: 0.0014 - mae: 1.6516
# Epoch 14/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5290 - accuracy: 0.0016 - mae: 1.6527
# Epoch 15/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.4700 - accuracy: 0.0017 - mae: 1.6459
# Epoch 16/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4902 - accuracy: 0.0024 - mae: 1.6488
# Epoch 17/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.4336 - accuracy: 0.0021 - mae: 1.6362
# Epoch 18/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.3966 - accuracy: 0.0023 - mae: 1.6277
# Epoch 19/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.3727 - accuracy: 0.0019 - mae: 1.6276
# Epoch 20/50
# 163/163 [==============================] - 2s 14ms/step - loss: 4.3522 - accuracy: 0.0013 - mae: 1.6254
# Epoch 21/50
# 163/163 [==============================] - 3s 16ms/step - loss: 4.2896 - accuracy: 0.0021 - mae: 1.6038
# Epoch 22/50
# 163/163 [==============================] - 2s 15ms/step - loss: 4.3438 - accuracy: 0.0019 - mae: 1.6182
# Epoch 23/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2362 - accuracy: 0.0015 - mae: 1.5952
# Epoch 24/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1965 - accuracy: 0.0014 - mae: 1.5882
# Epoch 25/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.2018 - accuracy: 0.0017 - mae: 1.5975
# Epoch 26/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1332 - accuracy: 0.0017 - mae: 1.5768
# Epoch 27/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1362 - accuracy: 9.6330e-04 - mae: 1.5716
# Epoch 28/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1355 - accuracy: 0.0016 - mae: 1.5763
# Epoch 29/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0597 - accuracy: 0.0016 - mae: 1.5698
# Epoch 30/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.1423 - accuracy: 0.0013 - mae: 1.5690
# Epoch 31/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0314 - accuracy: 0.0019 - mae: 1.5592
# Epoch 32/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0041 - accuracy: 0.0018 - mae: 1.5558
# Epoch 33/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0130 - accuracy: 0.0020 - mae: 1.5481
# Epoch 34/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9794 - accuracy: 0.0024 - mae: 1.5446
# Epoch 35/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9087 - accuracy: 0.0017 - mae: 1.5350
# Epoch 36/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8846 - accuracy: 0.0022 - mae: 1.5211
# Epoch 37/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9357 - accuracy: 0.0023 - mae: 1.5391
# Epoch 38/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.8495 - accuracy: 0.0021 - mae: 1.5232
# Epoch 39/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8846 - accuracy: 0.0025 - mae: 1.5310
# Epoch 40/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8703 - accuracy: 0.0022 - mae: 1.5225
# Epoch 41/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8072 - accuracy: 0.0015 - mae: 1.5134
# Epoch 42/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7778 - accuracy: 0.0025 - mae: 1.5058
# Epoch 43/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7921 - accuracy: 0.0020 - mae: 1.5109
# Epoch 44/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7476 - accuracy: 0.0019 - mae: 1.5046
# Epoch 45/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7517 - accuracy: 0.0024 - mae: 1.5042
# Epoch 46/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6485 - accuracy: 0.0016 - mae: 1.4822
# Epoch 47/50
# 163/163 [==============================] - 2s 14ms/step - loss: 3.6841 - accuracy: 0.0017 - mae: 1.4944
# Epoch 48/50
# 163/163 [==============================] - 2s 15ms/step - loss: 3.6204 - accuracy: 0.0022 - mae: 1.4767
# Epoch 49/50
# 163/163 [==============================] - 2s 14ms/step - loss: 3.6014 - accuracy: 0.0021 - mae: 1.4719
# Epoch 50/50
# 163/163 [==============================] - 3s 16ms/step - loss: 3.6096 - accuracy: 0.0020 - mae: 1.4704
# 82/82 [==============================] - 1s 4ms/step
# MSE Score: 3.2797039695791166
# Acc Score: 0.2323699421965318
# Kappa Score: 0.5301984215348968
#
# --------Fold 3--------
#
# Training Word2Vec Model...
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 1, 300)            721200
#
#  lstm_9 (LSTM)               (None, 64)                93440
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 12ms/step - loss: 9.6537 - accuracy: 0.0027 - mae: 2.3849
# Epoch 2/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.9597 - accuracy: 3.8532e-04 - mae: 1.7340
# Epoch 3/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.8048 - accuracy: 4.8165e-04 - mae: 1.7103
# Epoch 4/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.6626 - accuracy: 6.7431e-04 - mae: 1.6829
# Epoch 5/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6704 - accuracy: 0.0014 - mae: 1.6784
# Epoch 6/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5778 - accuracy: 0.0013 - mae: 1.6640
# Epoch 7/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5905 - accuracy: 0.0013 - mae: 1.6731
# Epoch 8/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5961 - accuracy: 0.0014 - mae: 1.6717
# Epoch 9/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5872 - accuracy: 0.0015 - mae: 1.6637
# Epoch 10/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4967 - accuracy: 0.0016 - mae: 1.6461
# Epoch 11/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5659 - accuracy: 0.0019 - mae: 1.6668
# Epoch 12/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5028 - accuracy: 0.0018 - mae: 1.6502
# Epoch 13/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5176 - accuracy: 0.0013 - mae: 1.6513
# Epoch 14/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.5259 - accuracy: 0.0012 - mae: 1.6499
# Epoch 15/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4918 - accuracy: 0.0014 - mae: 1.6527
# Epoch 16/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5209 - accuracy: 0.0017 - mae: 1.6535
# Epoch 17/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4267 - accuracy: 0.0018 - mae: 1.6333
# Epoch 18/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3939 - accuracy: 0.0015 - mae: 1.6254
# Epoch 19/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3786 - accuracy: 0.0023 - mae: 1.6299
# Epoch 20/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3303 - accuracy: 0.0013 - mae: 1.6113
# Epoch 21/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2996 - accuracy: 0.0020 - mae: 1.6154
# Epoch 22/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2851 - accuracy: 0.0013 - mae: 1.6091
# Epoch 23/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2450 - accuracy: 0.0012 - mae: 1.5996
# Epoch 24/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1888 - accuracy: 0.0013 - mae: 1.5870
# Epoch 25/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1413 - accuracy: 0.0023 - mae: 1.5811
# Epoch 26/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1832 - accuracy: 0.0014 - mae: 1.5858
# Epoch 27/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0795 - accuracy: 0.0014 - mae: 1.5646
# Epoch 28/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0807 - accuracy: 0.0018 - mae: 1.5704
# Epoch 29/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0598 - accuracy: 0.0016 - mae: 1.5621
# Epoch 30/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0131 - accuracy: 0.0016 - mae: 1.5541
# Epoch 31/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0091 - accuracy: 0.0018 - mae: 1.5555
# Epoch 32/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.0259 - accuracy: 0.0019 - mae: 1.5584
# Epoch 33/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9808 - accuracy: 0.0018 - mae: 1.5575
# Epoch 34/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9351 - accuracy: 0.0021 - mae: 1.5368
# Epoch 35/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8942 - accuracy: 0.0015 - mae: 1.5334
# Epoch 36/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.8379 - accuracy: 0.0027 - mae: 1.5178
# Epoch 37/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.8801 - accuracy: 0.0020 - mae: 1.5273
# Epoch 38/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7799 - accuracy: 0.0014 - mae: 1.5095
# Epoch 39/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7716 - accuracy: 0.0021 - mae: 1.5063
# Epoch 40/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7642 - accuracy: 0.0018 - mae: 1.5077
# Epoch 41/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7527 - accuracy: 0.0016 - mae: 1.5062
# Epoch 42/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7572 - accuracy: 0.0020 - mae: 1.5083
# Epoch 43/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7237 - accuracy: 0.0015 - mae: 1.5004
# Epoch 44/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7012 - accuracy: 0.0016 - mae: 1.4956
# Epoch 45/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.6864 - accuracy: 0.0017 - mae: 1.4846
# Epoch 46/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.6604 - accuracy: 0.0019 - mae: 1.4820
# Epoch 47/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.5931 - accuracy: 0.0019 - mae: 1.4707
# Epoch 48/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.5961 - accuracy: 0.0019 - mae: 1.4727
# Epoch 49/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.5739 - accuracy: 0.0022 - mae: 1.4682
# Epoch 50/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6049 - accuracy: 0.0014 - mae: 1.4705
# 82/82 [==============================] - 1s 3ms/step
# MSE Score: 3.314886448255076
# Acc Score: 0.23853564547206166
# Kappa Score: 0.5437959835134673
#
# --------Fold 4--------
#
# Training Word2Vec Model...
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 1, 300)            721200
#
#  lstm_11 (LSTM)              (None, 64)                93440
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 12ms/step - loss: 9.7485 - accuracy: 0.0027 - mae: 2.3927
# Epoch 2/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.8642 - accuracy: 3.8532e-04 - mae: 1.7237
# Epoch 3/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.7515 - accuracy: 2.8899e-04 - mae: 1.7001
# Epoch 4/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6931 - accuracy: 7.7064e-04 - mae: 1.6778
# Epoch 5/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6842 - accuracy: 0.0012 - mae: 1.6872
# Epoch 6/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6697 - accuracy: 0.0017 - mae: 1.6784
# Epoch 7/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6111 - accuracy: 0.0013 - mae: 1.6610
# Epoch 8/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.5870 - accuracy: 0.0019 - mae: 1.6707
# Epoch 9/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5785 - accuracy: 0.0017 - mae: 1.6609
# Epoch 10/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.6056 - accuracy: 0.0019 - mae: 1.6737
# Epoch 11/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5466 - accuracy: 0.0016 - mae: 1.6522
# Epoch 12/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5276 - accuracy: 0.0021 - mae: 1.6546
# Epoch 13/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5837 - accuracy: 0.0017 - mae: 1.6634
# Epoch 14/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4459 - accuracy: 0.0017 - mae: 1.6378
# Epoch 15/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5244 - accuracy: 0.0019 - mae: 1.6527
# Epoch 16/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.4671 - accuracy: 0.0016 - mae: 1.6428
# Epoch 17/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4296 - accuracy: 0.0025 - mae: 1.6319
# Epoch 18/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3946 - accuracy: 0.0014 - mae: 1.6257
# Epoch 19/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4167 - accuracy: 0.0013 - mae: 1.6337
# Epoch 20/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3439 - accuracy: 0.0015 - mae: 1.6218
# Epoch 21/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3329 - accuracy: 0.0016 - mae: 1.6179
# Epoch 22/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2755 - accuracy: 0.0016 - mae: 1.6064
# Epoch 23/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2824 - accuracy: 0.0017 - mae: 1.6123
# Epoch 24/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2344 - accuracy: 0.0013 - mae: 1.5982
# Epoch 25/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1621 - accuracy: 0.0015 - mae: 1.5851
# Epoch 26/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1684 - accuracy: 0.0017 - mae: 1.5878
# Epoch 27/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1276 - accuracy: 0.0021 - mae: 1.5794
# Epoch 28/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0898 - accuracy: 0.0018 - mae: 1.5749
# Epoch 29/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0980 - accuracy: 0.0014 - mae: 1.5732
# Epoch 30/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0653 - accuracy: 0.0016 - mae: 1.5666
# Epoch 31/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0350 - accuracy: 0.0023 - mae: 1.5582
# Epoch 32/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1031 - accuracy: 0.0014 - mae: 1.5803
# Epoch 33/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0649 - accuracy: 0.0018 - mae: 1.5682
# Epoch 34/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9900 - accuracy: 0.0013 - mae: 1.5476
# Epoch 35/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9701 - accuracy: 0.0015 - mae: 1.5470
# Epoch 36/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.9469 - accuracy: 0.0013 - mae: 1.5444
# Epoch 37/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8688 - accuracy: 0.0015 - mae: 1.5315
# Epoch 38/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.9263 - accuracy: 0.0024 - mae: 1.5417
# Epoch 39/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8560 - accuracy: 0.0015 - mae: 1.5214
# Epoch 40/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8187 - accuracy: 0.0018 - mae: 1.5197
# Epoch 41/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8161 - accuracy: 0.0020 - mae: 1.5183
# Epoch 42/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7741 - accuracy: 0.0014 - mae: 1.5097
# Epoch 43/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7352 - accuracy: 0.0017 - mae: 1.5007
# Epoch 44/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7009 - accuracy: 0.0014 - mae: 1.4967
# Epoch 45/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7146 - accuracy: 0.0024 - mae: 1.4989
# Epoch 46/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6938 - accuracy: 0.0014 - mae: 1.4951
# Epoch 47/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6804 - accuracy: 0.0020 - mae: 1.4955
# Epoch 48/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6409 - accuracy: 0.0018 - mae: 1.4843
# Epoch 49/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6255 - accuracy: 0.0017 - mae: 1.4823
# Epoch 50/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6076 - accuracy: 0.0022 - mae: 1.4754
# 82/82 [==============================] - 1s 3ms/step
# MSE Score: 3.3806166976409067
# Acc Score: 0.2073217726396917
# Kappa Score: 0.5345809025503891
#
# --------Fold 5--------
#
# Training Word2Vec Model...
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 1, 300)            721200
#
#  lstm_13 (LSTM)              (None, 64)                93440
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 814,705
# Trainable params: 814,705
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 163/163 [==============================] - 5s 11ms/step - loss: 9.8251 - accuracy: 0.0025 - mae: 2.4126
# Epoch 2/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.9645 - accuracy: 9.6330e-05 - mae: 1.7382
# Epoch 3/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.7801 - accuracy: 3.8532e-04 - mae: 1.7079
# Epoch 4/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.7231 - accuracy: 7.7064e-04 - mae: 1.6954
# Epoch 5/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.7082 - accuracy: 9.6330e-04 - mae: 1.6869
# Epoch 6/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6923 - accuracy: 0.0013 - mae: 1.6878
# Epoch 7/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.6573 - accuracy: 0.0016 - mae: 1.6796
# Epoch 8/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5833 - accuracy: 0.0011 - mae: 1.6661
# Epoch 9/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5626 - accuracy: 0.0013 - mae: 1.6647
# Epoch 10/50
# 163/163 [==============================] - 2s 11ms/step - loss: 4.5777 - accuracy: 0.0015 - mae: 1.6702
# Epoch 11/50
# 163/163 [==============================] - 2s 15ms/step - loss: 4.5349 - accuracy: 0.0015 - mae: 1.6657
# Epoch 12/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.4877 - accuracy: 0.0022 - mae: 1.6543
# Epoch 13/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.5048 - accuracy: 0.0013 - mae: 1.6502
# Epoch 14/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4883 - accuracy: 0.0012 - mae: 1.6556
# Epoch 15/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4886 - accuracy: 0.0017 - mae: 1.6463
# Epoch 16/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.4749 - accuracy: 0.0013 - mae: 1.6518
# Epoch 17/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.3807 - accuracy: 0.0015 - mae: 1.6308
# Epoch 18/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.4255 - accuracy: 0.0013 - mae: 1.6403
# Epoch 19/50
# 163/163 [==============================] - 2s 14ms/step - loss: 4.3588 - accuracy: 0.0016 - mae: 1.6280
# Epoch 20/50
# 163/163 [==============================] - 2s 14ms/step - loss: 4.3338 - accuracy: 0.0014 - mae: 1.6250
# Epoch 21/50
# 163/163 [==============================] - 2s 14ms/step - loss: 4.2873 - accuracy: 0.0014 - mae: 1.6119
# Epoch 22/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.2273 - accuracy: 0.0013 - mae: 1.6079
# Epoch 23/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.2641 - accuracy: 0.0013 - mae: 1.6098
# Epoch 24/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.2062 - accuracy: 0.0014 - mae: 1.6005
# Epoch 25/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.2036 - accuracy: 9.6330e-04 - mae: 1.6006
# Epoch 26/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.1429 - accuracy: 9.6330e-04 - mae: 1.5846
# Epoch 27/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.1128 - accuracy: 0.0011 - mae: 1.5855
# Epoch 28/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.0995 - accuracy: 0.0011 - mae: 1.5676
# Epoch 29/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.1070 - accuracy: 0.0013 - mae: 1.5811
# Epoch 30/50
# 163/163 [==============================] - 2s 12ms/step - loss: 4.0783 - accuracy: 0.0012 - mae: 1.5662
# Epoch 31/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.0754 - accuracy: 0.0019 - mae: 1.5677
# Epoch 32/50
# 163/163 [==============================] - 2s 13ms/step - loss: 4.0110 - accuracy: 0.0022 - mae: 1.5547
# Epoch 33/50
# 163/163 [==============================] - 2s 14ms/step - loss: 4.0281 - accuracy: 0.0015 - mae: 1.5630
# Epoch 34/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.9493 - accuracy: 0.0019 - mae: 1.5464
# Epoch 35/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.9031 - accuracy: 0.0021 - mae: 1.5351
# Epoch 36/50
# 163/163 [==============================] - 2s 14ms/step - loss: 3.8922 - accuracy: 0.0022 - mae: 1.5272
# Epoch 37/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.8550 - accuracy: 0.0023 - mae: 1.5296
# Epoch 38/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8626 - accuracy: 0.0017 - mae: 1.5271
# Epoch 39/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.8201 - accuracy: 0.0023 - mae: 1.5210
# Epoch 40/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.7678 - accuracy: 0.0023 - mae: 1.5087
# Epoch 41/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.7628 - accuracy: 0.0023 - mae: 1.5042
# Epoch 42/50
# 163/163 [==============================] - 2s 12ms/step - loss: 3.6998 - accuracy: 0.0014 - mae: 1.4923
# Epoch 43/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7003 - accuracy: 0.0021 - mae: 1.4948
# Epoch 44/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.7038 - accuracy: 0.0021 - mae: 1.4957
# Epoch 45/50
# 163/163 [==============================] - 2s 15ms/step - loss: 3.6425 - accuracy: 0.0018 - mae: 1.4870
# Epoch 46/50
# 163/163 [==============================] - 2s 14ms/step - loss: 3.6449 - accuracy: 0.0018 - mae: 1.4808
# Epoch 47/50
# 163/163 [==============================] - 2s 15ms/step - loss: 3.5909 - accuracy: 0.0030 - mae: 1.4734
# Epoch 48/50
# 163/163 [==============================] - 2s 15ms/step - loss: 3.5861 - accuracy: 0.0021 - mae: 1.4674
# Epoch 49/50
# 163/163 [==============================] - 2s 13ms/step - loss: 3.5630 - accuracy: 0.0022 - mae: 1.4711
# Epoch 50/50
# 163/163 [==============================] - 2s 11ms/step - loss: 3.5342 - accuracy: 0.0016 - mae: 1.4621
# 82/82 [==============================] - 1s 3ms/step
# MSE Score: 3.418175267536737
# Acc Score: 0.23853564547206166
# Kappa Score: 0.5412423906779891

# %%
print("Average MSE score after a 5-fold cross validation: ",np.around(np.array(mses).mean(),decimals=4))
print("Average Accuracy score after a 5-fold cross validation: ",np.around(np.array(accuracies).mean(),decimals=4))
print("Average Kappa score after a 5-fold cross validation: ",np.around(np.array(cohen_kappa_scores).mean(),decimals=4))
# Out:
# Average MSE score after a 5-fold cross validation:  3.2903
# Average Accuracy score after a 5-fold cross validation:  0.2313
# Average Kappa score after a 5-fold cross validation:  0.5402
